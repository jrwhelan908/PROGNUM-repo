# %%
print("Enter MONTH DAY YEAR")
input ("M,D,Y")
J = 367*Y- (7*(Y+ ((M+9)/12))/4)- (3*(((Y+ ((M-9)/7))/100)+1)/4)+ (275*M/9)+D+1721028.5
print("JD =", J)
# Out:
# Enter MONTH DAY YEAR
# M,D,Y 1,4,1700
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 print("Enter MONTH DAY YEAR")
#       2 input ("M,D,Y")
# ----> 3 J = 367*Y- (7*(Y+ ((M+9)/12))/4)- (3*(((Y+ ((M-9)/7))/100)+1)/4)+ (275*M/9)+D+1721028.5
#       4 print("JD =", J)
#
# NameError: name 'Y' is not defined
